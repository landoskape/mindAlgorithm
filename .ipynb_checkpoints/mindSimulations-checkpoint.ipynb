# %% [markdown]
# ### This notebook is for research on the MIND paper from Tank lab-
# - paper: https://www.biorxiv.org/content/10.1101/418939v2.full.pdf
#
# ### Goals
# 1. Run some simulations from the MIND paper to replicate Figure 1
#     - use the [RatInABox](https://github.com/TomGeorge1234/RatInABox) software to assist with simulations (at least for an agent trajectory, maybe more). Currently the RatInABox repository is located here: C:\Users\andrew\Documents\gitRepositories\RatInABox
# 2. Once I have a working model, try installing multiple environments in the same network of neurons, with the remapping performed in a few different ways. The different ways are listed below in the section "ideas to test".
#
# ### Perspective
# There is an open question in hippocampal neuroscience (I think...) about how spatial coding and recoding occurs. In particular, it is not known whether remapping is random and orthogonal, or constrained by intrinsic hippocampal architecture. I think it could be interesting and fruitful to combine a model of latent space (e.g., MIND) with simulated activity patterns based on experimentally-predicted assumptions about remapping and hippocampal architecture to learn how each assumptions affects the global manifold and each local manifold.
#
# ### Ideas to Test
# 1. Losonczy lab - Geiller et al., 2021 - specific connection patterns between place cells and local inhibitory neurons
# 2. Spruston lab - The MEC/LEC anatomy - constrained inputs from MEC/LEC that are better than usual at driving plateau potentials

# %%
# %load_ext autoreload
# %autoreload 2

# Inclusions
import socket
import sys, os
if socket.gethostname()=='Andrews-MacBook-Pro.local':
    sys.path.append("/Users/landauland/Documents/GitHub/RatInABox")#os.path.join('C:/', 'Users','andrew','Documents','GitHub','RatInABox'))
else:
    sys.path.append(os.path.join('C:/', 'Users','andrew','Documents','gitRepositories','RatInABox'))

import time
import numpy as np
import numba as nb
import scipy
from scipy.spatial.distance import squareform, pdist, cdist
import matplotlib.pyplot as plt
import simulateHippocampalData as simData 
import mind_mindModel1 as mind
import mind_ppca1 as mppca

from tqdm.notebook import tqdm, trange

# %%
# Generate and plot some place cells and grid cells
NP = 50 # number of place cells
NG = 50 # number of grid cells
boxLength = 88 # 88cm box length (square arena)
gNoiseAmp = 1/100000 # noise standard deviation relative to signal standard deviation
placeWidth = 41.6 # place field with in cm (full-width at half-maximum of an isotropic gaussian function)
numGridModules = 4 # number of grid modules (in increasing scale)
gridExpansion = 1.3 # relative scale increase of each consecutive grid module
baseGridSpacing = 39.8 # cm
baseGridWidth = 27.4 # cm (full-width at half-maximum of an isotropic gaussian function)

# %%
xpos,ypos = simData.getBoxCoord(boxLength) 

# Create Library of Place Cells
xcPlace,ycPlace = zip(*[simData.randCentroid(boxLength) for _ in range(NP)]) # centroid
placeLibrary = np.array([simData.getPlaceMap(xcPlace[n],ycPlace[n],xpos,ypos,placeWidth) for n in range(NP)])

# Create Library of Grid Cells
xcGrid,ycGrid = zip(*[simData.randCentroid(boxLength) for _ in range(NG)]) # centroid
spGrid = tuple(baseGridSpacing * (gridExpansion**np.random.randint(0,numGridModules)) for _ in range(NG)) # grid spacing
agGrid = tuple(np.pi/3*np.random.random() for _ in range(NG)) # angle of lattice
gridLibrary = np.array([simData.getGridMap(xcGrid[n],ycGrid[n],xpos,ypos,spGrid[n],agGrid[n]) for n in range(NG)])

# Sanity Check!!
print(f'Shape of place library is {np.shape(placeLibrary)}')
print(f'Shape of grid library is {np.shape(gridLibrary)}')
print(f"Min/max of place library is {np.min(placeLibrary):.1f}/{np.max(placeLibrary)}")
print(f"Min/max of grid library is {np.min(gridLibrary):.1f}/{np.max(gridLibrary)}")
# Out:
# Shape of place library is (50, 88, 88)
# Shape of grid library is (50, 88, 88)
# Min/max of place library is 0.0/1.0
# Min/max of grid library is -0.5/1.0

# %%
# Show Examples
numExamplesEach = 10
f, ax = plt.subplots(2,numExamplesEach,figsize=(24,4))
for n in range(numExamplesEach):
    ax[0,n].imshow(placeLibrary[np.random.randint(NP)])
    ax[1,n].imshow(gridLibrary[np.random.randint(NG)])
    ax[0,n].axis('off')
    ax[1,n].axis('off')

# %%
# Generate a trajectory in the environment
Env = simData.Environment({"scale":boxLength/100}) # (RatInABox uses meters)
Ag = simData.Agent(Env,{"dt":0.1,"speed_mean":0.12})
for i in range(50000): # Use standard number of datapoints, independent of time step
    Ag.update();

# Get trajectory variables
t, pos = np.array(Ag.history["t"]), np.array(Ag.history["pos"])
pos = pos * 100 # convert back to centimeters (to use as index)
posidx = np.floor(pos).astype('int8')

# %%
# Return place and grid cell activity along trajectory, with noise if requested
placeActivitySignal = placeLibrary[:,posidx[:,0],posidx[:,1]].T
gridActivitySignal = gridLibrary[:,posidx[:,0],posidx[:,1]].T
hippoActivitySignal = np.concatenate((placeActivitySignal,gridActivitySignal),axis=1)

# Add Noise
gNoiseAmp = 1/10
placeActivity = placeActivitySignal + np.random.normal(0,gNoiseAmp,placeActivitySignal.shape)
hippoActivity = hippoActivitySignal + np.random.normal(0,gNoiseAmp,hippoActivitySignal.shape)

# %%
# Plot Trajectory and plot examples of place cell and grid cell activity overlaid on trajectory
numExamplesEach = 2
pexidx = np.random.randint(0,NP,numExamplesEach)
gexidx = np.random.randint(0,NG,numExamplesEach)
f, ax = plt.subplots(1,numExamplesEach*2+1,figsize=(24,4))
# Ag.plot_trajectory(ax=ax[0])
plt.set_cmap('cool')
ax[0].scatter(pos[:,0],pos[:,1],s=15,c=range(pos.shape[0]),alpha=0.3)
plt.set_cmap('jet')
for n in range(numExamplesEach):
    ax[n+1].scatter(pos[:,0],pos[:,1],s=5,c=placeActivity[:,pexidx[n]])
    ax[n+1+numExamplesEach].scatter(pos[:,0],pos[:,1],s=5,c=hippoActivity[:,NP+gexidx[n]])

# %%
opts = {'numScafPoints':800,'nLeaf':40}
numTrees = 50

placeMind = mind.mindModel(opts)
placeMind.addData(placeActivity)
placeMind.constructForest(numTrees,simpleUpdates=True)
placeMind.summarizeForest()
placeMind.constructScaffold()
# Out:
# Fitting PPCA Tree 1/50, eta: nan seconds...
# Fitting PPCA Tree 2/50, eta: nan seconds...
# Fitting PPCA Tree 3/50, eta: 226.8 seconds...
# Fitting PPCA Tree 4/50, eta: 223.9 seconds...
# Fitting PPCA Tree 5/50, eta: 222.7 seconds...
# Fitting PPCA Tree 6/50, eta: 222.3 seconds...
# Fitting PPCA Tree 7/50, eta: 221.0 seconds...
# Fitting PPCA Tree 8/50, eta: 220.2 seconds...
# Fitting PPCA Tree 9/50, eta: 219.2 seconds...
# Fitting PPCA Tree 10/50, eta: 218.8 seconds...
# Fitting PPCA Tree 11/50, eta: 218.4 seconds...
# Fitting PPCA Tree 12/50, eta: 218.3 seconds...
# Fitting PPCA Tree 13/50, eta: 224.1 seconds...
# Fitting PPCA Tree 14/50, eta: 225.0 seconds...
# Fitting PPCA Tree 15/50, eta: 226.6 seconds...
# Fitting PPCA Tree 16/50, eta: 226.6 seconds...
# Fitting PPCA Tree 17/50, eta: 226.5 seconds...
# Fitting PPCA Tree 18/50, eta: 225.9 seconds...
# Fitting PPCA Tree 19/50, eta: 225.8 seconds...
# Fitting PPCA Tree 20/50, eta: 225.5 seconds...
# Fitting PPCA Tree 21/50, eta: 225.1 seconds...
# Fitting PPCA Tree 22/50, eta: 224.8 seconds...
# Fitting PPCA Tree 23/50, eta: 224.6 seconds...
# Fitting PPCA Tree 24/50, eta: 224.1 seconds...
# Fitting PPCA Tree 25/50, eta: 223.9 seconds...
# Fitting PPCA Tree 26/50, eta: 223.5 seconds...
# Fitting PPCA Tree 27/50, eta: 223.1 seconds...
# Fitting PPCA Tree 28/50, eta: 222.9 seconds...
# Fitting PPCA Tree 29/50, eta: 222.9 seconds...
# Fitting PPCA Tree 30/50, eta: 222.7 seconds...
# Fitting PPCA Tree 31/50, eta: 222.4 seconds...
# Fitting PPCA Tree 32/50, eta: 222.1 seconds...
# Fitting PPCA Tree 33/50, eta: 222.0 seconds...
# Fitting PPCA Tree 34/50, eta: 221.8 seconds...
# Fitting PPCA Tree 35/50, eta: 221.7 seconds...
# Fitting PPCA Tree 36/50, eta: 221.6 seconds...
# Fitting PPCA Tree 37/50, eta: 221.5 seconds...
# Fitting PPCA Tree 38/50, eta: 221.3 seconds...
# Fitting PPCA Tree 39/50, eta: 221.1 seconds...
# Fitting PPCA Tree 40/50, eta: 221.6 seconds...
# Fitting PPCA Tree 41/50, eta: 221.7 seconds...
# Fitting PPCA Tree 42/50, eta: 221.9 seconds...
# Fitting PPCA Tree 43/50, eta: 222.0 seconds...
# Fitting PPCA Tree 44/50, eta: 222.0 seconds...
# Fitting PPCA Tree 45/50, eta: 221.9 seconds...
# Fitting PPCA Tree 46/50, eta: 221.9 seconds...
# Fitting PPCA Tree 47/50, eta: 221.8 seconds...
# Fitting PPCA Tree 48/50, eta: 221.7 seconds...
# Fitting PPCA Tree 49/50, eta: 221.6 seconds...
# Fitting PPCA Tree 50/50, eta: 221.6 seconds...
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))

# %%
opts = {'numScafPoints':800,'nLeaf':40}
numTrees = 50

hippoMind = mind.mindModel(opts)
hippoMind.addData(hippoActivity)
hippoMind.constructForest(numTrees,simpleUpdates=True)
hippoMind.summarizeForest()
hippoMind.constructScaffold()
# Out:
# Fitting PPCA Tree 1/50, eta: nan seconds...
# Fitting PPCA Tree 2/50, eta: nan seconds...
# Fitting PPCA Tree 3/50, eta: 246.2 seconds...
# Fitting PPCA Tree 4/50, eta: 252.8 seconds...
# Fitting PPCA Tree 5/50, eta: 253.3 seconds...
# Fitting PPCA Tree 6/50, eta: 253.5 seconds...
# Fitting PPCA Tree 7/50, eta: 256.5 seconds...
# Fitting PPCA Tree 8/50, eta: 253.9 seconds...
# Fitting PPCA Tree 9/50, eta: 254.2 seconds...
# Fitting PPCA Tree 10/50, eta: 253.1 seconds...
# Fitting PPCA Tree 11/50, eta: 253.2 seconds...
# Fitting PPCA Tree 12/50, eta: 254.2 seconds...
# Fitting PPCA Tree 13/50, eta: 254.2 seconds...
# Fitting PPCA Tree 14/50, eta: 254.0 seconds...
# Fitting PPCA Tree 15/50, eta: 253.6 seconds...
# Fitting PPCA Tree 16/50, eta: 252.6 seconds...
# Fitting PPCA Tree 17/50, eta: 253.4 seconds...
# Fitting PPCA Tree 18/50, eta: 253.8 seconds...
# Fitting PPCA Tree 19/50, eta: 253.1 seconds...
# Fitting PPCA Tree 20/50, eta: 253.8 seconds...
# Fitting PPCA Tree 21/50, eta: 255.1 seconds...
# Fitting PPCA Tree 22/50, eta: 256.3 seconds...
# Fitting PPCA Tree 23/50, eta: 256.7 seconds...
# Fitting PPCA Tree 24/50, eta: 256.4 seconds...
# Fitting PPCA Tree 25/50, eta: 255.6 seconds...
# Fitting PPCA Tree 26/50, eta: 255.1 seconds...
# Fitting PPCA Tree 27/50, eta: 255.0 seconds...
# Fitting PPCA Tree 28/50, eta: 254.8 seconds...
# Fitting PPCA Tree 29/50, eta: 254.6 seconds...
# Fitting PPCA Tree 30/50, eta: 255.2 seconds...
# Fitting PPCA Tree 31/50, eta: 255.1 seconds...
# Fitting PPCA Tree 32/50, eta: 255.5 seconds...
# Fitting PPCA Tree 33/50, eta: 255.2 seconds...
# Fitting PPCA Tree 34/50, eta: 254.9 seconds...
# Fitting PPCA Tree 35/50, eta: 254.7 seconds...
# Fitting PPCA Tree 36/50, eta: 254.8 seconds...

# %%
# Compute probability of transitions from one point to all other possible points
xp4,yp4 = simData.getBoxCoord(boxLength,4)
xpv = xp4.reshape(-1)
ypv = yp4.reshape(-1)
placeMesh = (placeLibrary[:,xpv,ypv].T - placeMind.drPPCA.u) @ placeMind.drPPCA.v
hippoMesh = (np.concatenate((placeLibrary[:,xpv,ypv].T,gridLibrary[:,xpv,ypv].T),axis=1) - hippoMind.drPPCA.u) @ hippoMind.drPPCA.v

xC,yC = 22,22
placeCenter = (placeLibrary[:,xC,yC].T - placeMind.drPPCA.u) @ placeMind.drPPCA.v
hippoCenter = (np.concatenate((placeLibrary[:,xC,yC].reshape(1,-1),gridLibrary[:,xC,yC].reshape(1,-1)),axis=1) - hippoMind.drPPCA.u) @ hippoMind.drPPCA.v

placeMeshProb = placeMind.smartForestLikelihood(np.repeat(placeCenter.reshape(1,-1),placeMesh.shape[0],axis=0), placeMesh)
hippoMeshProb = hippoMind.smartForestLikelihood(np.repeat(hippoCenter.reshape(1,-1),hippoMesh.shape[0],axis=0), hippoMesh)

fig,ax = plt.subplots(1,2,figsize=(11,4))

placeNonzero = np.where(placeMeshProb != 0)[0]
placeZero = np.where(placeMeshProb == 0)[0]
cLimits = (np.min(np.log(placeMeshProb[placeNonzero])), np.max(np.log(placeMeshProb[placeNonzero])))
xx = ax[0].scatter(xpv[placeNonzero],ypv[placeNonzero],s=50,c=np.log(placeMeshProb[placeNonzero]),vmin=cLimits[0],vmax=cLimits[1])
ax[0].scatter(xpv[placeZero],ypv[placeZero],s=3,c=cLimits[0]*np.ones_like(xpv[placeZero]),vmin=cLimits[0],vmax=cLimits[1])
ax[0].scatter(xC,yC,s=100,c='k')
ax[0].scatter(xC,yC,s=45,c='w')
ax[0].scatter(xC,yC,s=15,c='k')
plt.colorbar(xx,ax=ax[0],label='logProb')

hippoNonzero = np.where(hippoMeshProb != 0)[0]
hippoZero = np.where(hippoMeshProb == 0)[0]
cLimits = (np.min(np.log(hippoMeshProb[hippoNonzero])), np.max(np.log(hippoMeshProb[hippoNonzero])))
xx = ax[1].scatter(xpv[hippoNonzero],ypv[hippoNonzero],s=50,c=np.log(hippoMeshProb[hippoNonzero]),vmin=cLimits[0],vmax=cLimits[1])
ax[1].scatter(xpv[hippoZero],ypv[hippoZero],s=3,c=cLimits[0]*np.ones_like(xpv[hippoZero]),vmin=cLimits[0],vmax=cLimits[1])
ax[1].scatter(xC,yC,s=100,c='k')
ax[1].scatter(xC,yC,s=45,c='w')
ax[1].scatter(xC,yC,s=15,c='k')
plt.colorbar(xx,ax=ax[1],label='logProb')

# %%
# Some print check statements for mapping scaffold transition probabilies to distance
xMind = hippoMind
print(np.any(xMind.scafDist==np.inf))
print(np.all(xMind.scafGridProb>=0) and np.all(xMind.scafGridProb<=np.inf))
print(np.all(xMind.scafTrProb>=0) and np.all(xMind.scafTrProb<=1))
print(np.allclose(np.sum(xMind.scafTrProb,axis=1),1))
print(np.all(xMind.scafLocalDist>=0))
print(np.any(xMind.scafLocalDist==np.inf))
print(np.all(xMind.scafGlobalDist>=0))
print(np.any(xMind.scafGlobalDist==np.inf))
# Out:
# False
# True
# True
# True
# True
# True
# True
# False

# %%
# Optimize Forward and Backward Mapping
dimRec = np.arange(6,11)
placeMind.optimizeForwardMapping(dimRec, numIterations=5, frac2test=0.1, kOptions=None, lamOptions=None)
placeMind.optimizeBackwardMapping(dimRec, numIterations=5, frac2test=0.1, kOptions=None, lamOptions=None)
hippoMind.optimizeForwardMapping(dimRec, numIterations=5, frac2test=0.1, kOptions=None, lamOptions=None)
hippoMind.optimizeBackwardMapping(dimRec, numIterations=5, frac2test=0.1, kOptions=None, lamOptions=None)
# Out:
# Optimizing backward mapping finished for dims=[ 6  7  8  9 10] in 135.2 seconds.
# Alert: the largest k (k=20) was selected for dim=[6]. Consider expanding search.
# Alert: the largest lambda (10.0) was selected for dim=[ 6  7  8  9 10]. Consider expanding search.

# %%
# Now run data through mds and reconstructions with different dimensionalities
dimRec = np.arange(1,11)
placeError = np.zeros(len(dimRec))
hippoError = np.zeros(len(dimRec))
for dri, drval in enumerate(dimRec):
    print(f"Working on reconstruction, D={drval}")
    cpfk, cpfl = placeMind.getMappingParameters(drval, 'forward')
    cpbk, cpbl = placeMind.getMappingParameters(drval, 'backward')
    chfk, chfl = hippoMind.getMappingParameters(drval, 'forward')
    chbk, chbl = hippoMind.getMappingParameters(drval, 'backward')
    # Produce a mapping of the landmark points
    placeMap = placeMind.performMDS(drval, updateObject=False, returnCoord=True, verbose=False)
    hippoMap = hippoMind.performMDS(drval, updateObject=False, returnCoord=True, verbose=False)
    # Do forward and backward mapping of all the data
    cpForward = placeMind.mapping(placeMind.drData, placeMind.scafData, placeMap, k=cpfk, lam=cpfl)
    cpReconstruction = placeMind.mapping(cpForward, placeMap, placeMind.scafData, k=cpbk, lam=cpbl)
    chForward = hippoMind.mapping(hippoMind.drData, hippoMind.scafData, hippoMap, k=chfk, lam=chfl)
    chReconstruction = hippoMind.mapping(chForward, hippoMap, hippoMind.scafData, k=chbk, lam=chbl)
    # And Compute Error
    placeError[dri] = mind.reconstructionError(placeMind.drData, cpReconstruction)
    hippoError[dri] = mind.reconstructionError(hippoMind.drData, chReconstruction)
# Out:
# Working on reconstruction, D=1
# Working on reconstruction, D=2
# Working on reconstruction, D=3
# Working on reconstruction, D=4
# Working on reconstruction, D=5
# Working on reconstruction, D=6
# Working on reconstruction, D=7
# Working on reconstruction, D=8
# Working on reconstruction, D=9
# Working on reconstruction, D=10

# %%
fig, ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(dimRec, placeError, c='k')
ax[0].set_xlabel('NumDims')
ax[0].set_ylabel('Error')
ax[0].set_title('Place Error')
ax[1].plot(dimRec, hippoError, c='k')
ax[1].set_xlabel('NumDims')
ax[1].set_ylabel('Error')
ax[1].set_title('Hippo Error')
# Out:
# Text(0.5, 1.0, 'Hippo Error')

# %% [markdown]
# ## Some other code I've used for testing various things

# %%
# Return place and grid cell activity along trajectory, with noise if requested
placeActivitySignal = placeLibrary[:,posidx[:,0],posidx[:,1]].T
gridActivitySignal = gridLibrary[:,posidx[:,0],posidx[:,1]].T
hippoActivitySignal = np.concatenate((placeActivitySignal,gridActivitySignal),axis=1)

# Add Noise
gNoiseAmp = 1/10
placeActivity = placeActivitySignal + np.random.normal(0,gNoiseAmp,placeActivitySignal.shape)
hippoActivity = hippoActivitySignal + np.random.normal(0,gNoiseAmp,hippoActivitySignal.shape)

# %%
from sklearn.datasets import make_spd_matrix as spd
xx = spd(500)
G = np.linalg.cholesky(xx)
print(f"Determinant: {np.linalg.det(xx)}")
print(f"SmartDet:    {(np.prod(np.diag(G)))**2}")
print(f"WeirdDet:    {np.exp(2*np.sum(np.log(np.diag(G))))}")
print(f"Log Determinant:   {np.log(np.linalg.det(xx))}")
print(f"Log Det Cholesky:  {2*np.log(np.linalg.det(G))}")
print(f"Log Smart Chol:    {2*np.log(np.prod(np.diag(G)))}")
print(f"Log Smarter Chol:  {2*np.sum(np.log(np.diag(G)))}")
# Out:
# Determinant: 2.1204785052493824e-215
# SmartDet:    2.1204785150201225e-215
# WeirdDet:    2.12047851502009e-215
# Log Determinant:   -494.3041532204813
# Log Det Cholesky:  -494.3041532158734
# Log Smart Chol:    -494.3041532158735
# Log Smarter Chol:  -494.3041532158735

# %%
prob = np.random.randint(5, size=4) /4
print(prob)

result = np.where(prob > 0, prob, np.inf)
print(result)
np.log10(result, out=result, where=result > 0)
# -np.log(0)
# Out:
# [0. 1. 1. 1.]
# [inf  1.  1.  1.]
# array([inf,  0.,  0.,  0.])

# %%
def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for name, size in sorted(((name, sys.getsizeof(value)) for name, value in locals().items()),
                         key= lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))
# Out:
#                  hippoActivity: 61.0 MiB
#               chReconstruction: 13.4 MiB
#               cpReconstruction:  4.9 MiB
#                      cpForward:  4.3 MiB
#                      chForward:  4.3 MiB
#                   placeLibrary:  3.0 MiB
#                    gridLibrary:  3.0 MiB
#                            pos:  1.2 MiB
#                              t: 625.1 KiB
#                         posidx: 156.4 KiB

# %%
useTreeIdx = 0
pathIndices = placeMind.returnPathIndexLoop(placeMind.drData,useTreeIdx)
numPaths = len(placeMind.treeSummary[useTreeIdx])
randIndexDict = dict(zip(np.arange(numPaths),np.random.permutation(numPaths)))
plt.scatter(pos[:,0],pos[:,1],s=1,c=[randIndexDict[pi] for pi in pathIndices],alpha=0.7)

# %%
import numpy as np
import matplotlib.pyplot as plt
from heatMapCluster import heatmapcluster


def make_data(size, seed=None):
    if seed is not None:
        np.random.seed(seed)

    s = np.random.gamma([7, 6, 5], [6, 8, 6], size=(size[1], 3)).T
    i = np.random.choice(range(len(s)), size=size[0])
    x = s[i]

    t = np.random.gamma([8, 5, 6], [3, 3, 2.1], size=(size[0], 3)).T
    j = np.random.choice(range(len(t)), size=size[1])

    x += 1.1*t[j].T

    x += 2*np.random.randn(*size)

    row_labels = [('R%02d' % k) for k in range(x.shape[0])]
    col_labels = [('C%02d' % k) for k in range(x.shape[1])]

    return x, row_labels, col_labels


x, row_labels, col_labels = make_data(size=(64, 48), seed=123)

h = heatmapcluster(x, row_labels, col_labels,
                   num_row_clusters=3, num_col_clusters=0,
                   label_fontsize=6,
                   xlabel_rotation=-75,
                   cmap=plt.cm.coolwarm,
                   show_colorbar=True,
                   top_dendrogram=True)
plt.show()

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
data = pfScores[:,:10].T
weights = np.ones(data.shape[0])
udata = np.average(data, axis=0, weights=weights)
cdata = data - udata

# %%
data = pfScores[:,:10].T
weights = np.maximum(np.random.normal(0,0.2,(data.shape[0]))+1,0.1) #np.ones(data.shape[0])
udata = np.average(data, axis=0, weights=weights)
cdata = data - udata

torchData = torch.tensor(cdata, device=device).float().T; 
torchWeights = torch.tensor(weights, device=device).float();

# %time wcovData = (1/np.sum(weights)) * (cdata.T @ np.diag(weights) @ cdata)
# %time rcovData = np.cov(cdata.T, bias=True, aweights=weights)
# %time tcovData = torch.cov(torchData,correction=0,aweights=torchWeights)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# CPU times: total: 0 ns
# Wall time: 0 ns
# CPU times: total: 15.6 ms
# Wall time: 997 µs

# %%
torch.allclose(torch.tensor(wcovData,device=device).float(),tcovData)
# Out:
# True

# %%
xxx = np.arange(5).reshape(-1,1) + np.arange(5).reshape(1,-1)
xxx = xxx - np.diag(np.diag(xxx))
print(xxx)
print(squareform(xxx))
# Out:
# [[0 1 2 3 4]
#  [1 0 3 4 5]
#  [2 3 0 5 6]
#  [3 4 5 0 7]
#  [4 5 6 7 0]]
# [1 2 3 4 3 4 5 5 6 7]

# %%
nb.__version__
# Out:
# '0.55.1'

# %%
np.__version__
# Out:
# '1.21.5'

# %%
u.T.shape
# Out:
# (6, 800)

# %%
import numba as nb
import numpy as np

def fastGrid(data, u, iS, logDet, D): 
    N = data.shape[1] 
    probability = np.zeros((N,N))
    for n in range(N):
        udata = data - u[:,n].reshape(-1,1)
        cexparg = np.sum((iS[:,:,n] @ udata) * udata,axis=0)
        cloglikelihood = -D/2*np.log(2*np.pi) - 1/2*logDet[n] - cexparg/2
        probability[n,:] = np.exp(cloglikelihood)
    return probability

def mindGrid(data,u,iS,logDet,D):
    N = data.shape[1]
    probability = np.zeros((N,N))
    for n in range(N):
        cudata = data - u[:,n].reshape(D,1)
        cexparg = (-1/2) * np.sum((iS[:,:,n] @ cudata) * cudata, axis=0)
        cloglik = -D/2*np.log(2*np.pi) - 1/2*logDet[n] + cexparg
        probability[n,:] = np.exp(cloglik)
    return probability

@nb.njit(nb.float64[:,::1](nb.float64[:,::1],nb.float64[:,::1],nb.float64[:,:,::1],nb.float64[::1],nb.float64), nogil=True, parallel=True)
def fastGridNC(data, u, iS, logDet, D): 
    N = data.shape[0] 
    probability = np.zeros((N,N))
    for n in nb.prange(N):
        udata = np.zeros_like(data)
        # subtract mean
        for n1 in range(N):
            udata[n1,:] = data[n1,:] - u[n,:]
        cexpargmat = (udata @ iS[n]) * udata
        cexparg = np.zeros_like(logDet)
        for n1 in range(N):
            cexparg[n1] = np.sum(cexpargmat[n1,:])
        cloglikelihood = -D/2*np.log(2*np.pi) - 1/2*logDet[n] - cexparg/2
        probability[n,:] = np.exp(cloglikelihood)
    return probability

@nb.njit(nb.float64[:,::1](nb.float64[:,::1],nb.float64[:,::1],nb.float64[:,:,::1],nb.float64[::1],nb.float64), nogil=True, parallel=True)
def difGridNC(data, u, iS, logDet, D): 
    N = data.shape[0] 
    probability = np.zeros((N,N))
    for n in nb.prange(N):
        udata = np.zeros_like(data)
        # subtract mean
        for n1 in range(N):
            udata[n1] = data[n1] - u[n]
        cexpargmat = (udata @ iS[n]) * udata
        cexparg = np.zeros_like(logDet)
        for n1 in range(N):
            cexparg[n1] = np.sum(cexpargmat[n1])
        cloglikelihood = -D/2*np.log(2*np.pi) - 1/2*logDet[n] - cexparg/2
        probability[n] = np.exp(cloglikelihood)
    return probability

tt = 0
T = 5
data = pfLandmark
D,N = data.shape
v0 = np.zeros((N,N,T))
v1 = np.zeros((N,N,T))
v2 = np.zeros((N,N,T))
# for tt in range(T):
tt=0
tPathIdx = mind.returnPathIndexLoop(data, placeForest['tree'][tt])
u = placeForest['ppcaMeans'][tt][tPathIdx,:]
iS = placeForest['ppcaInvCovs'][tt][tPathIdx,:,:]
logDet = placeForest['ppcaLogDets'][tt][tPathIdx]

tdata = np.ascontiguousarray(data.T)
tu = u
tiS = iS
tLogDet = logDet

# v0[:,:,tt] = fastGrid(data,u.T,iS.transpose(1,2,0),logDet,D)
# v1[:,:,tt] = mindGrid(data,u.T,iS.transpose(1,2,0),logDet,D)
# v2[:,:,tt] = fastGridNC(tdata,tu,tiS,tlogDet,D)

# xxx = mind.smartGridProbability(pfLandmark, placeForest)
# yyy = mind.numbaGridProbability(pfLandmark, placeForest)
# %timeit v0 = fastGrid(data,u,iS,logDet,D)
# %timeit v1 = difGridNC(tdata,tu,tiS,tLogDet,D)
# %timeit v2 = fastGridNC(tdata,tu,tiS,tLogDet,D)

print(np.allclose(v0,v1))
print(np.allclose(v0,v2))
print(np.allclose(v1,v2))
print(np.allclose(xxx,yyy))
# Out:
# 59.7 ms ± 155 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.48 ms ± 63.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# True
# True
# True
# True

# %%
len(placeForest['tree'])
# Out:
# 5

# %%
import numpy as np 
N,D = 100,7
data = np.random.normal(0,1,(D,N))
u = np.random.normal(0,1,(D,N))
iS = np.random.normal(0,1,(D,D,N))
logDet = np.random.normal(10,1,N)

udata = np.random.normal(0,1,(D,N,N))
mexp = np.zeros((N,N))
for n1 in range(N):
    for n2 in range(N):
        mexp[n1,n2] = udata[:,n1,n2] @ iS[:,:,n2] @ udata[:,n1,n2]
einexp = np.einsum('dnm,ddm,dnm -> nm',udata, iS, udata) 

ein1 = np.einsum('ddm,dnm -> dnm', iS, udata)
ein2 = np.einsum('dnm,dnm -> nm', udata, ein1)
print(mexp.shape)
print(einexp.shape)
print(np.allclose(mexp,einexp.T))
print(np.allclose(mexp,ein2))
# Out:
# (100, 100)
# (100, 100)
# False
# False
